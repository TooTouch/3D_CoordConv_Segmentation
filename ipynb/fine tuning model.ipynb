# %%
from keras import models
from keras import layers as KL
import sys

sys.path.append('../code/')

from metrics import weighted_dice_coefficient_loss, dice_coefficient
# Out:
# C:\Users\wogur\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model_dir = '../model/UNET_3D_0.h5'

# %%
model = models.load_model(model_dir, custom_objects={'weighted_dice_coefficient_loss': weighted_dice_coefficient_loss,'dice_coefficient':dice_coefficient})

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 1, 128, 128,  0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 64, 128, 128, 1792        input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 128, 128, 0           conv3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 64, 128, 128, 110656      activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 128, 128, 0           conv3d_2[0][0]
# ...

# %%
x = KL.Conv3D(filters=16, kernel_size=(3,3,3), padding='same', activation='relu', name='fine_tune_conv3d_0')(model.layers[-3].output)
x = KL.Conv3D(filters=16, kernel_size=(3,3,3), padding='same', activation='relu', name='fine_tune_conv3d_1')(x)
output = KL.Conv3D(filters=8, kernel_size=(3,3,3), padding='same', activation='softmax', name='fine_tune_conv3d_2')(x)

# %%
model2 = models.Model(inputs=model.input, outputs=output)

# %%
model2.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 1, 128, 128,  0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 64, 128, 128, 1792        input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 128, 128, 0           conv3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 64, 128, 128, 110656      activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 128, 128, 0           conv3d_2[0][0]
# ...
